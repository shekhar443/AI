# %% [markdown]
# # <font color = "#654789" > <b><i>Object Tracking based on color using OpenCV</b>
# <b><i>NAKKA SHEKHAR</b>
# * [linkedin](https://www.linkedin.com/in/nakka-shekhar-2019a987/)
# * [github](https://github.com/shekhar443/AI)

# %% [markdown]
# ### BGR to HSV

# %%
# dst = cs2.cvtColor(src,cv2.COLOR_BGR2HSV)
# hsv = cv2.cvtColor(blurred,cv2.COLOR_BGR2HSV)

# %% [markdown]
# ### Minimum Enclosing Circle

# %%
#((x,y),radius) = cv2.minEnclosingCircle(countourArea)
#((x,y),radius) = cv2.minEnclosingCircle(c)

# %% [markdown]
# ### Moments to Find Center of the Area

# %%
#variable=cv2.moments(countourArea)
#M=cv2.moments(c)

# %% [markdown]
# ### Drawing a Circle

# %%
#cv2.circle(src,(x,y),int(radius),color,thickness)
#cv2.circle(frame,(int(x),int(y)),int(radius),(0,255,255),2)

# %%
#cv2.circle(frame,center(x,y),5,(0,0,255),-1)

# %% [markdown]
# ## Object Tracking based on color

# %%
import imutils
import cv2

redLower = (157, 93, 203)
redUpper = (179, 255, 255)

camera=cv2.VideoCapture(0)

while True:

        (grabbed, frame) = camera.read()

        frame = imutils.resize(frame, width=600)
        blurred = cv2.GaussianBlur(frame, (11, 11), 0)
        hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)

        mask = cv2.inRange(hsv, redLower, redUpper)
        mask = cv2.erode(mask, None, iterations=2)
        mask = cv2.dilate(mask, None, iterations=2)


        cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,
                cv2.CHAIN_APPROX_SIMPLE)[-2]
        center = None
        if len(cnts) > 0:
                c = max(cnts, key=cv2.contourArea)
                ((x, y), radius) = cv2.minEnclosingCircle(c)
                M = cv2.moments(c)
                center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))
                if radius > 10:
                        cv2.circle(frame, (int(x), int(y)), int(radius),
                                (0, 255, 255), 2)
                        cv2.circle(frame, center, 5, (0, 0, 255), -1)
                        print(center,radius)
                        if radius > 250:
                                print("stop")
                        else:
                                if(center[0]<150):
                                        print("Left")
                                elif(center[0]>450):
                                        print("Right")
                                elif(radius<250):
                                        print("Front")
                                else:
                                        print("Stop")
        cv2.imshow("Frame", frame)
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
                break

camera.release()
cv2.destroyAllWindows()
# Out:
# (287, 277) 27.421802520751953
# Front
# (289, 275) 25.16455841064453
# Front
# (289, 275) 25.16455841064453
# Front
# (290, 276) 24.42344856262207
# Front
# (290, 273) 26.856197357177734
# Front
# (291, 272) 26.19647216796875
# Front
# (291, 272) 26.19647216796875
# Front
# (291, 272) 25.53928565979004
# Front
# (291, 272) 25.53928565979004
# Front
# (292, 273) 26.19647216796875
# Front
# (291, 277) 26.19647216796875
# Front
# (238, 169) 24.010513305664062
# Front
# (240, 169) 16.620868682861328
# Front
# (291, 270) 19.813995361328125
# Front
# (290, 271) 19.115629196166992
# Front
# (293, 271) 17.219274520874023
# Front
# (293, 271) 17.219274520874023
# Front
# (290, 276) 22.59434700012207
# Front
# (290, 276) 22.59434700012207
# Front
# (290, 276) 22.59434700012207
# Front
# (291, 276) 22.192440032958984
# Front
# (290, 277) 23.307823181152344
# Front
# (291, 275) 22.94023895263672
# Front
# (290, 275) 22.85237693786621
# Front
# (290, 275) 22.85237693786621
# Front
# ...
